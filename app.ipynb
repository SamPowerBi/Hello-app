# %%
import yfinance as yf
import pandas as pd

# %%
ticker_symbol = "AAPL"
start_date = "2023-01-01"
end_date = "2024-01-01"

stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Close'], label='Close Price')
plt.title(f'{ticker_symbol} Stock Price (Last Year)')
plt.xlabel('Date')
plt.ylabel('Stock Price (USD)')
plt.legend()
plt.show()

# %%
import streamlit as st

# %%
# Title
st.title('Stock Price Analysis App')

# Sidebar with user input
ticker_symbol = st.text_input('Enter Stock Ticker:', 'AAPL')
start_date = st.date_input('Start Date', pd.to_datetime('2023-01-01'))
end_date = st.date_input('End Date', pd.to_datetime('2024-01-01'))

# Download stock data
stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)

# Display stock data
st.write(f"## {ticker_symbol} Stock Data (Last Year)")
st.write(stock_data)

# Plot closing prices
st.line_chart(stock_data['Close'])
# Out:
# 2024-01-03 14:28:52.328
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\ganes\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# [*********************100%%**********************]  1 of 1 completed
# DeltaGenerator()
